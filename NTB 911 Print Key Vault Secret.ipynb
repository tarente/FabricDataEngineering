# %%
# %run "NTB 000 Utils"
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 60, Finished, Available, Finished)

# %%
## Variables
strAKVURL   = 'https://akv-test01.vault.azure.net/'
strAKVKey01 = 'key-patrickleblanc'
strAKVKey02 = 'key-1charsecretNotDot'
strAKVKey03 = 'key-2charsecretNotDot'
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 61, Finished, Available, Finished)

# %%
## Get AVK Value
strAKVValue01 = notebookutils.credentials.getSecret(strAKVURL, strAKVKey01)
intAKVValue01 = len(strAKVValue01)
strAKVValue02 = notebookutils.credentials.getSecret(strAKVURL, strAKVKey02)
intAKVValue02 = len(strAKVValue02)
strAKVValue03 = notebookutils.credentials.getSecret(strAKVURL, strAKVKey03)
intAKVValue03 = len(strAKVValue03)
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 62, Finished, Available, Finished)

# %%
## Print strAKVKey01
strPrintableAKVValue01Long = fnGetPrintableSecretLong(strAKVValue01, '|', True)
intPrintableAKVValue01Long = len(strPrintableAKVValue01Long)

strPrintableAKVValue01Short = fnGetPrintableSecretShort (strAKVValue01, boolDebugValue = True)
intPrintableAKVValue01Short = len(strPrintableAKVValue01Short)

print(f"{strAKVKey01} [REDACTED] = '{strAKVValue01}', lenght = {intAKVValue01}.")
print(f"{strAKVKey01} [Long]     = '{strPrintableAKVValue01Long}', lenght = {intPrintableAKVValue01Long}.")
print(f"{strAKVKey01} [Short]    = '{strPrintableAKVValue01Short}', lenght = {intPrintableAKVValue01Short}.")
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 63, Finished, Available, Finished)
# key-patrickleblanc [REDACTED] = '[REDACTED]', lenght = 68.
# key-patrickleblanc [Long]     = '|D|o|n|'|t| |t|e|l|l| |a|n|y|b|o|d|y|,| |b|u|t| |P|a|t|r|i|c|k| |L|e|B|l|a|n|c| |L|O|V|E|S| |L|O|V|E|S| |L|O|V|E|S| |i|c|e| |c|r|e|a|m|.|', lenght = 137.
# key-patrickleblanc [Short]    = 'Don't tell anybody, but Patrick LeBlanc LOVES LOVES LOVES ice cream.', lenght = 69.

# %%
## Print strAKVKey01
strPrintableAKVValue01Long = fnGetPrintableSecretLong(strAKVValue01, chr(29), True)
intPrintableAKVValue01Long = len(strPrintableAKVValue01Long)

strPrintableAKVValue01Short = fnGetPrintableSecretShort (strAKVValue01, boolDebugValue = True)
intPrintableAKVValue01Short = len(strPrintableAKVValue01Short)

print(f"{strAKVKey01} [REDACTED] = '{strAKVValue01}', lenght = {intAKVValue01}.")
print(f"{strAKVKey01} [Long]     = '{strPrintableAKVValue01Long}', lenght = {intPrintableAKVValue01Long}.")
print(f"{strAKVKey01} [Short]    = '{strPrintableAKVValue01Short}', lenght = {intPrintableAKVValue01Short}.")
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 64, Finished, Available, Finished)
# key-patrickleblanc [REDACTED] = '[REDACTED]', lenght = 68.
# key-patrickleblanc [Long]     = 'Don't tell anybody, but Patrick LeBlanc LOVES LOVES LOVES ice cream.', lenght = 137.
# key-patrickleblanc [Short]    = 'Don't tell anybody, but Patrick LeBlanc LOVES LOVES LOVES ice cream.', lenght = 69.

# %%
## Print strAKVKey02
strPrintableAKVValue02Long = fnGetPrintableSecretLong(strAKVValue02, '|', True)
intPrintableAKVValue02Long = len(strPrintableAKVValue02Long)

strPrintableAKVValue02Short = fnGetPrintableSecretShort (strAKVValue02, boolDebugValue = True)
intPrintableAKVValue02Short = len(strPrintableAKVValue02Short)

print(f"{strAKVKey02} [REDACTED] = '{strAKVValue02}', lenght = {intAKVValue02}.")
print(f"{strAKVKey02} [Long]     = '{strPrintableAKVValue02Long}', lenght = {intPrintableAKVValue02Long}.")
print(f"{strAKVKey02} [Short]    = '{strPrintableAKVValue02Short}', lenght = {intPrintableAKVValue02Short}.")
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 65, Finished, Available, Finished)
# key-1charsecretNotDot [REDACTED] = '[REDACTED]', lenght = 1.
# key-1charsecretNotDot [Long]     = '|[REDACTED]|', lenght = 3.
# key-1charsecretNotDot [Short]    = '[REDACTED]', lenght = 2.

# %%
## Print strAKVKey02
strPrintableAKVValue02Long = fnGetPrintableSecretLong(strAKVValue02, chr(29), True)
intPrintableAKVValue02Long = len(strPrintableAKVValue02Long)

strPrintableAKVValue02Short = fnGetPrintableSecretShort (strAKVValue02, boolDebugValue = True)
intPrintableAKVValue02Short = len(strPrintableAKVValue02Short)

print(f"{strAKVKey02} [REDACTED] = '{strAKVValue02}', lenght = {intAKVValue02}.")
print(f"{strAKVKey02} [Long]     = '{strPrintableAKVValue02Long}', lenght = {intPrintableAKVValue02Long}.")
print(f"{strAKVKey02} [Short]    = '{strPrintableAKVValue02Short}', lenght = {intPrintableAKVValue02Short}.")
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 66, Finished, Available, Finished)
# key-1charsecretNotDot [REDACTED] = '[REDACTED]', lenght = 1.
# key-1charsecretNotDot [Long]     = '[REDACTED]', lenght = 3.
# key-1charsecretNotDot [Short]    = '[REDACTED]', lenght = 2.

# %%
## Print strAKVKey03
strPrintableAKVValue03Long = fnGetPrintableSecretLong(strAKVValue03, '|', True)
intPrintableAKVValue03Long = len(strPrintableAKVValue03Long)

strPrintableAKVValue03Short = fnGetPrintableSecretShort (strAKVValue03, boolDebugValue = True)
intPrintableAKVValue03Short = len(strPrintableAKVValue03Short)

print(f"{strAKVKey03} [REDACTED] = '{strAKVValue03}', lenght = {intAKVValue03}.")
print(f"{strAKVKey03} [Long]     = '{strPrintableAKVValue03Long}', lenght = {intPrintableAKVValue03Long}.")
print(f"{strAKVKey03} [Short]    = '{strPrintableAKVValue03Short}', lenght = {intPrintableAKVValue03Short}.")
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 67, Finished, Available, Finished)
# key-2charsecretNotDot [REDACTED] = '[REDACTED]', lenght = 2.
# key-2charsecretNotDot [Long]     = '|£|£|', lenght = 5.
# key-2charsecretNotDot [Short]    = '££', lenght = 3.

# %%
## Print strAKVKey03
strPrintableAKVValue03Long = fnGetPrintableSecretLong(strAKVValue03, chr(29), True)
intPrintableAKVValue03Long = len(strPrintableAKVValue03Long)

strPrintableAKVValue03Short = fnGetPrintableSecretShort (strAKVValue03, boolDebugValue = True)
intPrintableAKVValue03Short = len(strPrintableAKVValue03Short)

print(f"{strAKVKey03} [REDACTED] = '{strAKVValue03}', lenght = {intAKVValue03}.")
print(f"{strAKVKey03} [Long]     = '{strPrintableAKVValue03Long}', lenght = {intPrintableAKVValue03Long}.")
print(f"{strAKVKey03} [Short]    = '{strPrintableAKVValue03Short}', lenght = {intPrintableAKVValue03Short}.")
# Out:
# StatementMeta(, 819f7f63-2442-40be-beca-fa02209396ce, 68, Finished, Available, Finished)
# key-2charsecretNotDot [REDACTED] = '[REDACTED]', lenght = 2.
# key-2charsecretNotDot [Long]     = '££', lenght = 5.
# key-2charsecretNotDot [Short]    = '££', lenght = 3.
